# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('covid19.csv')

# %%
df.shape
# Out:
# (321, 6)

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.shape
# Out:
# (321, 6)

# %%
df.groupby('Region').sum().head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1640\1384902467.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Region').sum().head()
#              Confirmed  Deaths  Recovered
# Region
# Afghanistan       1939      60        252
# Albania            766      30        455
# Algeria           3848     444       1702
# Andorra            743      42        423
# Angola              27       2          7

# %%
df.groupby('Region')['Confirmed'].sum().sort_values(ascending = True)
# Out:
# Region
# Yemen                          6
# Western Sahara                 6
# Bhutan                         7
# Papua New Guinea               8
# Sao Tome and Principe          8
#                           ...
# UK                        166441
# France                    166543
# Italy                     203591
# Spain                     236899
# US                       1039909
# Name: Confirmed, Length: 187, dtype: int64

# %%
a = df.groupby('Region')
a

# %%
for Region,Region_df in a:
    print(Region_df)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
#         Date State   Region  Confirmed  Deaths  Recovered
# 1  4/29/2020   NaN  Albania        766      30        455
#         Date State   Region  Confirmed  Deaths  Recovered
# 2  4/29/2020   NaN  Algeria       3848     444       1702
#         Date State   Region  Confirmed  Deaths  Recovered
# 3  4/29/2020   NaN  Andorra        743      42        423
#         Date State  Region  Confirmed  Deaths  Recovered
# 4  4/29/2020   NaN  Angola         27       2          7
#         Date State               Region  Confirmed  Deaths  Recovered
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11
#         Date State     Region  Confirmed  Deaths  Recovered
# 6  4/29/2020   NaN  Argentina       4285     214       1192
#         Date State   Region  Confirmed  Deaths  Recovered
# 7  4/29/2020   NaN  Armenia       1932      30        900
# ...

# %%
df.groupby('Region')['Recovered'].sum()
# Out:
# Region
# Afghanistan            252
# Albania                455
# Algeria               1702
# Andorra                423
# Angola                   7
#                       ...
# West Bank and Gaza      71
# Western Sahara           5
# Yemen                    1
# Zambia                  54
# Zimbabwe                 5
# Name: Recovered, Length: 187, dtype: int64

# %%
df[df.Confirmed < 5]
# Out:
#           Date                         State          Region  Confirmed  \
# 184  4/29/2020                      Anguilla              UK          3
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 284  4/29/2020                     Recovered          Canada          0
# 285  4/29/2020                     Recovered              US          0
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# 305  4/29/2020                         Tibet  Mainland China          1
#
#      Deaths  Recovered
# 184       0          3
# 203       1          0
# 284       0      20327
# 285       0     120720
# 289       0          0
# 305       0          1

# %%
df.shape
# Out:
# (321, 6)

# %%
df = df[~(df.Confirmed < 5000  )]

# %%
df[(df.Confirmed > 5000)]
# Out:
#           Date       State      Region  Confirmed  Deaths  Recovered
# 8    4/29/2020         NaN     Austria      15402     580      12779
# 12   4/29/2020         NaN  Bangladesh       7103     163        150
# 14   4/29/2020         NaN     Belarus      13181      84       2072
# 15   4/29/2020         NaN     Belgium      47859    7501      11283
# 22   4/29/2020         NaN      Brazil      79685    5513      34132
# ..         ...         ...         ...        ...     ...        ...
# 302  4/29/2020   Tennessee          US      10366     195          0
# 303  4/29/2020       Texas          US      27257     754          0
# 311  4/29/2020    Virginia          US      14962     522          0
# 312  4/29/2020  Washington          US      14070     801          0
# 315  4/29/2020   Wisconsin          US       6520     308          0
#
# [78 rows x 6 columns]

# %%
df.tail
# Out:
# <bound method NDFrame.tail of           Date       State      Region  Confirmed  Deaths  Recovered
# 8    4/29/2020         NaN     Austria      15402     580      12779
# 12   4/29/2020         NaN  Bangladesh       7103     163        150
# 14   4/29/2020         NaN     Belarus      13181      84       2072
# 15   4/29/2020         NaN     Belgium      47859    7501      11283
# 22   4/29/2020         NaN      Brazil      79685    5513      34132
# ..         ...         ...         ...        ...     ...        ...
# 302  4/29/2020   Tennessee          US      10366     195          0
# 303  4/29/2020       Texas          US      27257     754          0
# 311  4/29/2020    Virginia          US      14962     522          0
# 312  4/29/2020  Washington          US      14070     801          0
# 315  4/29/2020   Wisconsin          US       6520     308          0
#
# [78 rows x 6 columns]>

# %%
df.groupby('Region').Deaths.sum().sort_values( ascending = True).head(50)
# Out:
# Region
# Qatar                      10
# Singapore                  14
# Belarus                    84
# United Arab Emirates       98
# Malaysia                  100
# South Africa              103
# Serbia                    125
# Saudi Arabia              157
# Bangladesh                163
# Panama                    178
# Norway                    207
# Israel                    215
# Chile                     216
# Czech Republic            227
# South Korea               247
# Ukraine                   250
# Colombia                  278
# Dominican Republic        293
# Pakistan                  343
# Egypt                     380
# Japan                     413
# Denmark                   443
# Philippines               558
# Austria                   580
# Poland                    624
# Romania                   693
# Indonesia                 784
# Ecuador                   883
# Peru                      943
# Russia                    972
# ...

# %%
df.shape
# Out:
# (78, 6)

# %%
df.head(55)
# Out:
#           Date        State                Region  Confirmed  Deaths  \
# 8    4/29/2020          NaN               Austria      15402     580
# 12   4/29/2020          NaN            Bangladesh       7103     163
# 14   4/29/2020          NaN               Belarus      13181      84
# 15   4/29/2020          NaN               Belgium      47859    7501
# 22   4/29/2020          NaN                Brazil      79685    5513
# 33   4/29/2020          NaN                 Chile      14885     216
# 34   4/29/2020          NaN              Colombia       6207     278
# 41   4/29/2020          NaN        Czech Republic       7579     227
# 42   4/29/2020          NaN               Denmark       9008     443
# 46   4/29/2020          NaN    Dominican Republic       6652     293
# 47   4/29/2020          NaN               Ecuador      24675     883
# 48   4/29/2020          NaN                 Egypt       5268     380
# 57   4/29/2020          NaN                France     165093   24087
# ...

# %%
df['active_cases'] = df['Confirmed'] - df['Recovered'] - df['Deaths']
df.tail()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1640\856508492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['active_cases'] = df['Confirmed'] - df['Recovered'] - df['Deaths']
#           Date       State Region  Confirmed  Deaths  Recovered  active_cases
# 302  4/29/2020   Tennessee     US      10366     195          0         10171
# 303  4/29/2020       Texas     US      27257     754          0         26503
# 311  4/29/2020    Virginia     US      14962     522          0         14440
# 312  4/29/2020  Washington     US      14070     801          0         13269
# 315  4/29/2020   Wisconsin     US       6520     308          0          6212

# %%
df.head(50)
# Out:
#           Date       State                Region  Confirmed  Deaths  \
# 8    4/29/2020         NaN               Austria      15402     580
# 12   4/29/2020         NaN            Bangladesh       7103     163
# 14   4/29/2020         NaN               Belarus      13181      84
# 15   4/29/2020         NaN               Belgium      47859    7501
# 22   4/29/2020         NaN                Brazil      79685    5513
# 33   4/29/2020         NaN                 Chile      14885     216
# 34   4/29/2020         NaN              Colombia       6207     278
# 41   4/29/2020         NaN        Czech Republic       7579     227
# 42   4/29/2020         NaN               Denmark       9008     443
# 46   4/29/2020         NaN    Dominican Republic       6652     293
# 47   4/29/2020         NaN               Ecuador      24675     883
# 48   4/29/2020         NaN                 Egypt       5268     380
# 57   4/29/2020         NaN                France     165093   24087
# ...

# %%
df = df.drop(columns = ['State'])

# %%
df = pd.pivot_table(df , values = ['Confirmed','Deaths', 'Recovered','active_cases'],index = 'Region', aggfunc = max)

# %%
df['Recovery_Rate'] = df['Recovered'] * 100 / df['Confirmed']

# %%
df['Mortality_Rate'] = df['Deaths'] * 100 / df['Confirmed']

# %%
df.style.background_gradient(cmap = 'binary')
# Out:
# <style type="text/css">
# #T_9c58a_row0_col0, #T_9c58a_row6_col0, #T_9c58a_row11_col1, #T_9c58a_row27_col0, #T_9c58a_row29_col1, #T_9c58a_row31_col3, #T_9c58a_row32_col1, #T_9c58a_row35_col1, #T_9c58a_row48_col3 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_9c58a_row0_col1, #T_9c58a_row1_col4, #T_9c58a_row8_col2, #T_9c58a_row18_col3, #T_9c58a_row28_col3, #T_9c58a_row30_col1, #T_9c58a_row31_col1, #T_9c58a_row31_col2, #T_9c58a_row34_col0, #T_9c58a_row36_col2, #T_9c58a_row37_col3, #T_9c58a_row48_col0 {
#   background-color: #fafafa;
#   color: #000000;
# }
# #T_9c58a_row0_col2, #T_9c58a_row15_col0, #T_9c58a_row29_col0 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# ...

# %%
df['zscore'] = (df.Confirmed - df.Confirmed.mean())/df.Confirmed.std()
df.head(5)
# Out:
#             Confirmed  Deaths  Recovered  active_cases  Recovery_Rate  \
# Region
# Austria         15402     580      12779          2043      82.969744
# Bangladesh       7103     163        150          6790       2.111784
# Belarus         13181      84       2072         11025      15.719596
# Belgium         47859    7501      11283         29075      23.575503
# Brazil          79685    5513      34132         40040      42.833658
#
#             Mortality_Rate    zscore
# Region
# Austria           3.765745 -0.467008
# Bangladesh        2.294805 -0.590301
# Belarus           0.637281 -0.500004
# Belgium          15.673123  0.015182
# Brazil            6.918492  0.487998

# %%
 #df.to_csv("covidf.csv")

# %%
df.columns
# Out:
# Index(['Confirmed', 'Deaths', 'Recovered', 'active_cases', 'Recovery_Rate',
#        'Mortality_Rate', 'zscore'],
#       dtype='object')

# %%
import numpy as np

# %%
df.mean(axis = 'index')
# Out:
# Confirmed         4.683708e+04
# Deaths            3.772551e+03
# Recovered         1.560971e+04
# active_cases      2.745482e+04
# Recovery_Rate     3.144518e+01
# Mortality_Rate    5.161686e+00
# zscore           -2.718914e-17
# dtype: float64

# %%
df.median(axis = 'index')
# Out:
# Confirmed         15641.000000
# Deaths              624.000000
# Recovered          3025.000000
# active_cases       9502.000000
# Recovery_Rate        23.575503
# Mortality_Rate        3.970618
# zscore               -0.463458
# dtype: float64

# %%
#df.mode(axis = 'index')

# %%
df.std(axis = 'index')
# Out:
# Confirmed         67311.599831
# Deaths             7515.585107
# Recovered         29572.531008
# active_cases      47266.074587
# Recovery_Rate        27.049400
# Mortality_Rate        4.150447
# zscore                1.000000
# dtype: float64

# %%
df[df.Recovery_Rate>80]
# Out:
#                 Confirmed  Deaths  Recovered  active_cases  Recovery_Rate  \
# Region
# Austria             15402     580      12779          2043      82.969744
# Mainland China      68128    4512      63616             0      93.377172
# South Korea         10765     247       9059          1459      84.152346
#
#                 Mortality_Rate    zscore
# Region
# Austria               3.765745 -0.467008
# Mainland China        6.622828  0.316304
# South Korea           2.294473 -0.535897

# %%
df[df.Recovery_Rate<5]
# Out:
#              Confirmed  Deaths  Recovered  active_cases  Recovery_Rate  \
# Region
# Bangladesh        7103     163        150          6790       2.111784
# Canada           26610    1762          0         24848       0.000000
# Netherlands      38802    4711          0         34091       0.000000
# Norway            7710     207         32          7471       0.415045
# Sweden           20302    2462       1005         16835       4.950251
# UK              165221   26097          0        139124       0.000000
# US              299691   23477          0        276214       0.000000
#
#              Mortality_Rate    zscore
# Region
# Bangladesh         2.294805 -0.590301
# Canada             6.621571 -0.300499
# Netherlands       12.141127 -0.119371
# Norway             2.684825 -0.581283
# Sweden            12.126884 -0.394213
# UK                15.795208  1.758745
# US                 7.833735  3.756469
